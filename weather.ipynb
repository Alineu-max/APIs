# %%
baseurl = "http://api.weatherapi.com/v1"
Aline_Key = ""

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={Aline_Key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767069445,
#   'localtime': '2025-12-29 23:37'},
#  'current': {'last_updated_epoch': 1767069000,
#   'last_updated': '2025-12-29 23:30',
#   'temp_c': -4.4,
#   'temp_f': 24.1,
#   'is_day': 0,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#    'code': 1009},
#   'wind_mph': 11.4,
#   'wind_kph': 18.4,
#   'wind_degree': 295,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1026.0,
#   'pressure_in': 30.29,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 65,
#   'cloud': 100,
#   'feelslike_c': -10.5,
#   'feelslike_f': 13.1,
#   'windchill_c': -8.4,
#   'windchill_f': 16.9,
#   'heatindex_c': -2.3,
#   'heatindex_f': 27.8,
#   'dewpoint_c': -6.5,
#   'dewpoint_f': 20.2,
#   'vis_km': 16.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (24.1, 65)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={Aline_Key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f'weather for {location['name']}, {location['region']}')
        print(f'Temperature: {current['temp_f']}  F/ {current['temp_c']} C')
        print(f'Condition: {current['condition']['text']}')
        print(f'Humidity: {current['humidity']}%')
        print(f'Wind Speed: {current['wind_mph']} mph')

        print

    
    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Lihue")
# Out:
# weather for Lihue, Hawaii
# Temperature: 75.7  F/ 24.3 C
# Condition: Light rain
# Humidity: 78%
# Wind Speed: 9.6 mph

# %%
get_weather('Dayton')
# Out:
# weather for Dayton, Ohio
# Temperature: 21.0  F/ -6.1 C
# Condition: Overcast
# Humidity: 74%
# Wind Speed: 15.7 mph

# %%
get_weather('Dallas')
# Out:
# weather for Dallas, Texas
# Temperature: 39.9  F/ 4.4 C
# Condition: Partly cloudy
# Humidity: 36%
# Wind Speed: 9.8 mph

# %%
cities = ["kapaa", "Louisville", 'Lihue', "New York"]
weather_data = []
if response.status_code == 200:
   data = response.json()
   weather_data.append({
      "City": data['location']['name'],
      "Temperature": data['current']['temp_f'],
      "Condition": data['current']['condition'],
      "wind_mph": data['current']['wind_mph'],
      "humidity ": data['current']['humidity'],

   })
else:
   print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Louisville',
#   'Temperature': 24.1,
#   'Condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#    'code': 1009},
#   'wind_mph': 11.4,
#   'humidity ': 65}]

# %%
cities = ["kapaa", "Louisville", 'Lihue', "New York"]
weather_data = []

for city in cities:
   url = f"http://api.weatherapi.com/v1/current.json?key={Aline_Key}&q={city}"
   response = requests.get(url)

   if response.status_code == 200:
      data = response.json()
      weather_data.append({
         "City": data['location']['name'],
         "Temperature": data['current']['temp_f'],
         "Condition": data['current']['condition']['text'],
         "wind_mph": data['current']['wind_mph'],
         "humidity ": data['current']['humidity'],

         })
   else:
         print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Kapaa',
#   'Temperature': 75.4,
#   'Condition': 'Light rain',
#   'wind_mph': 9.6,
#   'humidity ': 78},
#  {'City': 'Louisville',
#   'Temperature': 24.1,
#   'Condition': 'Overcast',
#   'wind_mph': 10.7,
#   'humidity ': 65},
#  {'City': 'Lihue',
#   'Temperature': 75.4,
#   'Condition': 'Light rain',
#   'wind_mph': 9.6,
#   'humidity ': 78},
#  {'City': 'New York',
#   'Temperature': 30.9,
#   'Condition': 'Overcast',
#   'wind_mph': 20.6,
#   'humidity ': 45}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#          City  Temperature   Condition  wind_mph  humidity
# 0       Kapaa         75.4  Light rain       9.6         78
# 1  Louisville         24.1    Overcast      10.7         65
# 2       Lihue         75.4  Light rain       9.6         78
# 3    New York         30.9    Overcast      20.6         45

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
